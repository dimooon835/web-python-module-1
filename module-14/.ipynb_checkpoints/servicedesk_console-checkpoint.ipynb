# %% [markdown]
# # ЗАДАНИЕ: Консольное приложение для учета заявок на обслуживание оборудования
#
# Необходимо разработать консольное приложение ServiceDesk Console для учета заявок на техническое обслуживание оборудования в организации.
#
# В организации сотрудники используют различное оборудование: ноутбуки, компьютеры, принтеры, роутеры, сканеры и другую технику. Если оборудование выходит из строя или требует обслуживания, сотрудник оставляет заявку. Приложение должно позволять вести учет таких заявок, отслеживать их статус и получать краткую статистику.
#
# ## Цель работы:
# Создать консольную программу, которая позволяет добавлять, просматривать, искать, редактировать и удалять заявки на обслуживание оборудования, а также сохранять данные между запусками программы.
#
# ## Функциональные требования:
#
# ### 1. Главное меню
#
# При запуске программы пользователь должен видеть меню:
#
# ```txt
# === ServiceDesk Console ===
#
# 1. Добавить заявку
# 2. Показать все заявки
# 3. Найти заявку
# 4. Изменить статус заявки
# 5. Удалить заявку
# 6. Показать статистику
# 7. Сохранить данные
# 0. Выход
# ```
# Пользователь выбирает действие путем ввода номера пункта меню.
#
# ### 2. Добавление заявки
#
# Программа должна позволять добавить новую заявку.
#
# При создании заявки пользователь вводит следующие данные:
#
# ```txt
# - ФИО сотрудника
# - отдел сотрудника
# - тип оборудования
# - инвентарный номер оборудования
# - описание проблемы
# - приоритет заявки
# - статус заявки
# ```
#
# **Приоритет заявки может принимать одно из значений:**
#
# - низкий
# - средний
# - высокий
#
# **Статус заявки может принимать одно из значений:**
#
# - новая
# - в работе
# - выполнена
#
# **Каждой заявке должен автоматически присваиваться уникальный номер.**
#
# **Пример заявки:**
# ```txt
# Номер заявки: 1
# Сотрудник: Иванов Иван Иванович
# Отдел: Бухгалтерия
# Оборудование: Принтер
# Инвентарный номер: PR-1023
# Описание проблемы: Не печатает документы
# Приоритет: высокий
# Статус: новая
# ```
#
# ### 3. Просмотр всех заявок
#
# Программа должна выводить список всех созданных заявок.
#
# Для каждой заявки необходимо отображать:
# ```txt
# - номер заявки
# - ФИО сотрудника
# - отдел
# - тип оборудования
# - инвентарный номер
# - описание проблемы
# - приоритет
# - статус
# ```
#
# Если заявок нет, программа должна вывести сообщение:
#
# `Заявки отсутствуют.`
#
# ### 4. Поиск заявок
#
# Программа должна позволять искать заявки по разным параметрам.
#
# Необходимо реализовать поиск:
# ```txt
# - по ФИО сотрудника
# - по отделу
# - по статусу
# - по инвентарному номеру оборудования
# ```
#
# При выборе пункта `Найти заявку` пользователь должен выбрать критерий поиска, затем ввести значение для поиска.
#
# Пример меню поиска:
# ```txt
# 1. Поиск по сотруднику
# 2. Поиск по отделу
# 3. Поиск по статусу
# 4. Поиск по инвентарному номеру
# ```
# Если подходящие заявки найдены, программа выводит их список.
# Если заявок не найдено, программа выводит сообщение:
#
# `Заявки не найдены.`
#
# ### 5. Изменение статуса заявки
#
# Программа должна позволять изменить статус существующей заявки.
#
# Для изменения статуса пользователь вводит номер заявки, после чего выбирает новый статус:
# ```txt
# 1. новая
# 2. в работе
# 3. выполнена
# ```
#
# Если заявка с указанным номером существует, программа изменяет ее статус и выводит сообщение об успешном изменении.
#
# Если заявка не найдена, программа выводит сообщение:
#
# `Заявка с указанным номером не найдена.`
#
# ### 6. Удаление заявки
#
# Программа должна позволять удалить заявку.
#
# Для удаления пользователь вводит номер заявки.
#
# Если заявка с таким номером существует, программа удаляет ее и выводит сообщение:
#
# `Заявка успешно удалена.`
#
# Если заявка не найдена, программа выводит сообщение:
#
# `Заявка с указанным номером не найдена.`
#
# ### 7. Статистика
#
# Программа должна выводить краткую статистику по заявкам:
#
# - общее количество заявок
# - количество новых заявок
# - количество заявок в работе
# - количество выполненных заявок
# - количество заявок с высоким приоритетом
#
# Пример вывода:
# ```txt
# === Статистика ===
#
# Всего заявок: 10
# Новые: 3
# В работе: 4
# Выполнены: 3
# С высоким приоритетом: 2
# ```
#
# ### 8. Сохранение данных
#
# Программа должна сохранять данные о заявках в файл.
#
# Формат файла можно выбрать самостоятельно:
#
# - txt
# - csv
# - json
#
# После сохранения программа должна вывести сообщение:
#
# `Данные успешно сохранены.`
#
# ### 9. Загрузка данных
#
# При запуске программы необходимо загружать ранее сохраненные заявки из файла, если такой файл существует.
#
# Если файл отсутствует, программа начинает работу с пустым списком заявок.
#
# ### 10. Выход из программы
#
# При выборе пункта `0. Выход` программа должна завершить работу.
#
# Перед выходом желательно выполнить автоматическое сохранение данных в файл.
#
# Требования к обработке ошибок:
#
# 1. Программа не должна завершаться аварийно при некорректном вводе пользователя.
# 2. Если пользователь вводит неправильный пункт меню, необходимо вывести сообщение:
#
# `Некорректный выбор. Попробуйте снова.`
#
# 3. Если пользователь вводит несуществующий номер заявки, необходимо вывести сообщение:
#
# `Заявка с указанным номером не найдена.`
#
# 4. Если пользователь вводит недопустимый статус или приоритет, программа должна попросить повторить ввод.
#
# Требования к структуре программы:
#
# В программе рекомендуется использовать:
#
# - класс или структуру для хранения данных заявки
# - список или коллекцию для хранения всех заявок
# - отдельные функции или методы для:
#   - вывода меню
#   - добавления заявки
#   - просмотра заявок
#   - поиска заявок
#   - изменения статуса
#   - удаления заявки
#   - вывода статистики
#   - сохранения данных
#   - загрузки данных
#
# Пример структуры заявки:
#
# Заявка:
# - id
# - employeeName
# - department
# - equipmentType
# - inventoryNumber
# - problemDescription
# - priority
# - status
#
# Дополнительные требования:
#
# 1. Номер заявки должен быть уникальным.
# 2. После удаления заявки номера остальных заявок не должны изменяться.
# 3. При добавлении новой заявки номер должен быть больше, чем у всех уже существующих заявок.
# 4. Поиск должен работать без учета регистра букв.
# 5. Данные должны сохраняться между запусками программы.
#
# Результат выполнения работы:
#
# В результате должно быть создано консольное приложение ServiceDesk Console, которое позволяет вести учет заявок на обслуживание оборудования в организации и сохранять информацию о заявках между запусками программы.

# %%
import json
import os

file_name = "requests.json"

class Request:
    def __init__(self, id, employee_name, department, equipment_type, inventory_num, problem_desc, priority, status):
        self.id = id
        self.employee_name = employee_name
        self.department = department
        self.equipment_type = equipment_type
        self.inventory_num = inventory_num
        self.problem_desc = problem_desc
        self.priority = priority
        self.status = status

    def to_dict(self):
        return self.__dict__
    
    @staticmethod
    def from_dict(data):
        return Request(**data)


class FileManager:
    @staticmethod
    def load_data():
        if not os.path.exists(file_name):
            return []
        
        with open(file_name, "r", encoding="utf-8") as f:
            data = json.load(f)
            return [Request.from_dict(r) for r in data]

    @staticmethod
    def save_data(requests):
        with open(file_name, "w", encoding="utf-8") as f:
            json.dump([r.to_dict() for r in requests], f, ensure_ascii=False, indent=4)
        print("Данные сохранены")

class RequestManager:
    def __init__(self):
        self.requests = FileManager().load_data()

    def get_next_id(self):
        if not self.requests:
            return 1
        return max(r.id for r in self.requests) + 1

    def add_request(self):
        print("\n=== Добавление заявки ===")

        employee_name = input("ФИО сотрудника: ")
        department = input("Отдел сотрудника: ")
        equipment_type = input("Тип оборудования: ")
        inventory_num = input("Инвентарный номер: ")
        problem_desc = input("Описание проблемы: ")

        priority = input("Приоритет заявки (низкий/средний/высокий): ").lower()
        while priority not in ["низкий", "средний", "высокий"]:
            priority = input("Ошибка. Введите приоритет снова: ").lower()

        status = input("Статус заявки (новая/в работе/выполнена): ").lower()
        while status not in ["новая", "в работе", "выполнена"]:
            status = input("Ошибка. Введите статус снова: ").lower()

        new_request = Request(
            self.get_next_id(),
            employee_name,
            department,
            equipment_type,
            inventory_num,
            problem_desc,
            priority,
            status
        )

        self.requests.append(new_request)
        print("Заявка добавлена")

    def show_all(self):
        if not self.requests:
            print("Заявки отсутствуют")
            return
        
        for r in self.requests:
            print(f"""
    Номер заявки: {r.id}
    ФИО сотрудника: {r.employee_name}
    Отдел: {r.department}
    Тип оборудования: {r.equipment_type}
    Инвентарный номер: {r.inventory_num}
    Описание проблемы: {r.problem_desc}
    Приоритет: {r.priority}
    Статус: {r.status}
    -----------------------------------""")
            
    def search_requests(self):
        print("""
    1. По сотруднику
    2. По отделу
    3. По статусу
    4. По инвентарному номеру
    """)
        
        choice = input("Выбор: ")
        value = input("Введите значение: ").lower()

        found = []

        for r in self.requests:
            if choice == "1" and value in r.employee_name.lower():
                found.append(r)
            elif choice == "2" and value in r.department.lower():
                found.append(r)
            elif choice == "3" and value in r.status.lower():
                found.append(r)
            elif choice == "4" and value in r.inventory_num.lower():
                found.append(r)

        if not found:
            print("Заявки не найдены")
        else:
            for r in found:
                print(f"{r.id} | {r.employee_name} | {r.status}")

    def update_status(self):
        try:
            id = int(input("Введите номер заявки: "))
        except:
            print("Ошибка ввода")
            return
        
        for r in self.requests:
            if r.id == id:
                print("1. новая\n2. в работе\n3. выполнена")
                choice = input("Выберите статус: ")

                if choice == "1":
                    r.status = "новая"
                elif choice == "2":
                    r.status = "в работе"
                elif choice == "3":
                    r.status = "выполнена"
                else:
                    print("Некорректный ввод")
                    return
                
                print("Статус обновлён")
                return
            
        print("Заявка с указанным номером не найдена")

    def delete_request(self):
        try:
            id = int(input("Введите номер заявки: "))
        except:
            print("Ошибка ввода")
            return
        
        for r in self.requests:
            if r.id == id:
                self.requests.remove(r)
                print("Заявка удалена")
                return
        
        print("Заявка с указанным номером не найдена")

    def show_stats(self):
        total = len(self.requests)
        new = sum(1 for r in self.requests if r.status == "новая")
        in_progress = sum(1 for r in self.requests if r.status == "в работе")
        done = sum(1 for r in self.requests if r.status == "выполнена")
        high = sum(1 for r in self.requests if r.status == "высокий")

        print(f"""
    === Статистика ===

Всего заявок: {total}
Новые: {new}
В работе: {in_progress}
Выполнены: {done}
С высоким приоритетом: {high}
""")
    
class ServiceDesk:
    def __init__(self):
        self.manager = RequestManager()

    def menu(self):
        while True:
            print("""
    === ServiceDesk Console ===

    1. Добавить заявку
    2. Показать все заявки
    3. Найти заявку
    4. Изменить статус заявки
    5. Удалить заявку
    6. Показать статистику
    7. Сохранить данные
    0. Выход
    """)
            
            choice = input("Выбор: ")

            if choice == "1":
                self.manager.add_request()
            elif choice == "2":
                self.manager.show_all()
            elif choice == "3":
                self.manager.search_requests()
            elif choice == "4":
                self.manager.update_status()
            elif choice == "5":
                self.manager.delete_request()
            elif choice == "6":
                self.manager.show_stats()
            elif choice == "7":
                FileManager.save_data(self.manager.requests)
            elif choice == "0":
                FileManager.save_data(self.manager.requests)
                print("Выход...")
                break
            else:
                print("Некорректный выбор. Попробуйте снова")

if __name__ == "__main__":
    app = ServiceDesk()
    app.menu()
# Out:
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  2
#     Номер заявки: 1
#     ФИО сотрудника: Д.И.Л
#     Отдел: Бухгалтерия
#     Тип оборудования: Принтер
#     Инвентарный номер: PR-1023
#     Описание проблемы: Не печатает документы
#     Приоритет: высокий
#     Статус: новая
#     -----------------------------------
#
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  4
# Введите номер заявки:  1
# 1. новая
# 2. в работе
# 3. выполнена
# Выберите статус:  3
# Статус обновлён
#
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  2
#     Номер заявки: 1
#     ФИО сотрудника: Д.И.Л
#     Отдел: Бухгалтерия
#     Тип оборудования: Принтер
#     Инвентарный номер: PR-1023
#     Описание проблемы: Не печатает документы
#     Приоритет: высокий
#     Статус: выполнена
#     -----------------------------------
#
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  6
#     === Статистика ===
#
# Всего заявок: 1
# Новые: 0
# В работе: 0
# Выполнены: 1
# С высоким приоритетом: 0
#
#
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  7
# Данные сохранены
#
#     === ServiceDesk Console ===
#
#     1. Добавить заявку
#     2. Показать все заявки
#     3. Найти заявку
#     4. Изменить статус заявки
#     5. Удалить заявку
#     6. Показать статистику
#     7. Сохранить данные
#     0. Выход
# Выбор:  0
# Данные сохранены
# Выход...
